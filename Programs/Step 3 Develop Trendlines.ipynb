# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from scipy import stats
import os
import matplotlib.pyplot as plt

# %%
# Bring in the allyears dataframe created in step 2
outdatapath = os.path.join('..','output_data',f"AllMeansAndTests.csv")
all_years=pd.read_csv(outdatapath)
all_years.head()
# Out:
#    Year  Count in Smoking HH  Asthma Rate in Smoking HH  \
# 0  2006                 1727                  17.081644
# 1  2007                 1415                  17.667845
# 2  2008                 1450                  17.517241
# 3  2009                 1846                  18.093174
# 4  2010                 1700                  15.882353
#
#    Count Asthma in Smoking HH  \
# 0                         295
# 1                         250
# 2                         254
# 3                         334
# 4                         270
#
#    Asthmatic Child Difference P-Value for Smoking Status  \
# 0                                           0.000009
# 1                                           0.000004
# 2                                           0.000163
# 3                                           0.000002
# 4                                           0.011216
#
#   Asthmatic Child Difference Significant for Smoking Status  \
# ...

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
smk_asthma_bar = all_years["Asthma Rate in Smoking HH"].tolist()
nonsmk_asthma_bar = all_years["Asthma Rate in Non-Smoking HH"].tolist()
siglist = all_years["Asthmatic Child Difference Significant for Smoking Status"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_asthma_bar, color='darkgoldenrod', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Household")
plt.bar(r2, nonsmk_asthma_bar, color='royalblue', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child Asthma Rate in Smoking Vs. Non-Smoking Households 2006 through 2017")
plt.ylim(0,23)

plt.legend()

place = -1

for x,y in zip(x_axis,smk_asthma_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,nonsmk_asthma_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
plt.text(2005.5,21,"* Signifies significant difference between asthma rates \n between household types for a given year",
        fontsize=10)
plt.xlabel("Year")
plt.ylabel("Percent of Families with an Asthmatic Child")

# Save the Figure
plt.savefig(f"../Images/AsthmaVsSmoking.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
smk_bar = all_years["Autism Rate in Smoking HH"].tolist()
nonsmk_bar = all_years["Autism Rate in Non-Smoking HH"].tolist()
siglist = all_years["Autistic Child Difference Significant for Smoking Status"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_bar, color='darkturquoise', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Household")
plt.bar(r2, nonsmk_bar, color='peru', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child Atuism Rate in Smoking Vs. Non-Smoking Households 2006 through 2017")
plt.ylim(0,4.5)

plt.legend()

place = -1

for x,y in zip(x_axis,smk_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,nonsmk_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
plt.text(2005.5,4,"* Signifies significant difference between autism rates \n between household types for a given year",
        fontsize=10)
plt.xlabel("Year")
plt.ylabel("Percent of Families with an Autistic Child")

# Save the Figure
plt.savefig(f"../Images/AutismVsSmoking.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
smk_bar = all_years["ADHD/ADD Rate in Smoking HH"].tolist()
nonsmk_bar = all_years["ADHD/ADD Rate in Non-Smoking HH"].tolist()
siglist = all_years["ADHD/ADD Child Difference Significant for Smoking Status"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_bar, color='coral', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Household")
plt.bar(r2, nonsmk_bar, color='rebeccapurple', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child ADHD/ADD Rate in Smoking Vs. Non-Smoking Households 2006 through 2017")
plt.ylim(0,17)

plt.legend()

place = -1

for x,y in zip(x_axis,smk_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,nonsmk_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
plt.text(2005.5,15,"* Signifies significant difference between ADHD/ADD rates \n between household types for a given year",
        fontsize=10)
plt.xlabel("Year")
plt.ylabel("Percent of Families with a Child with ADHD or ADD")

# Save the Figure
plt.savefig(f"../Images/ADDVsSmoking.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
smk_bar = all_years["Concentration/Emotional/Behavior Rate in Smoking HH"].tolist()
nonsmk_bar = all_years["Concentration/Emotional/Behavior Rate in Non-Smoking HH"].tolist()
siglist = all_years["Concentration/Emotional/Behavior Difference Significant for Smoking Status"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_bar, color='darkorange', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Household")
plt.bar(r2, nonsmk_bar, color='olivedrab', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child with Behavioral Issues Rate in Smoking Vs. Non-Smoking Households 2006 through 2017")
plt.ylim(0,35)

plt.legend()

place = -1

for x,y in zip(x_axis,smk_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,nonsmk_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
plt.text(2005.5,30,"* Signifies significant difference between behavioral issues rates \n between household types for a given year",
        fontsize=10)
plt.xlabel("Year")
plt.ylabel("Percent of Families with a Child with Behavioral Issues")

# Save the Figure
plt.savefig(f"../Images/BehaviorVsSmoking.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
pov_asthma_bar = all_years["Asthma Rate in Impoverished HH"].tolist()
nonpov_asthma_bar = all_years["Asthma Rate in Non-Impoverished HH"].tolist()
siglist = all_years["Asthmatic Child Difference Significant for Poverty Status"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, pov_asthma_bar, color='darkgoldenrod', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Impoverished Household")
plt.bar(r2, nonpov_asthma_bar, color='royalblue', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Impoverished Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child Asthma Rate in Impoverished Vs. Non-Impoverished Households 2006 through 2017")
plt.ylim(0,23)

plt.legend()

place = -1

for x,y in zip(x_axis,pov_asthma_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,nonpov_asthma_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
plt.text(2005.5,21,"* Signifies significant difference between asthma rates \n between household types for a given year",
        fontsize=10)
plt.xlabel("Year")
plt.ylabel("Percent of Families with an Asthmatic Child")

# Save the Figure
plt.savefig(f"../Images/AsthmaVsPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
pov_adhd_bar = all_years["ADHD/ADD Rate in Impoverished HH"].tolist()
nonpov_adhd_bar = all_years["ADHD/ADD Rate in Non-Impoverished HH"].tolist()
siglist = all_years["ADHD/ADD Child Difference Significant for Poverty Status"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, pov_adhd_bar, color='coral', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Impoverished Household")
plt.bar(r2, nonpov_adhd_bar, color='rebeccapurple', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Impoverished Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child ADHD/ADD Rate in Impoverished Vs. Non-Impoverished Households 2006 through 2017")
plt.ylim(0,14)

plt.legend()

place = -1

for x,y in zip(x_axis,pov_adhd_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,nonpov_adhd_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
plt.text(2005.5,12.5,"* Signifies significant difference between ADHD/ADD rates \n between household types for a given year",
        fontsize=10)
plt.xlabel("Year")
plt.ylabel("Percent of Families with a Child with ADHD/ADD")

# Save the Figure
plt.savefig(f"../Images/ADHD_ADDVsPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
pov_autism_bar = all_years["Autism Rate in Impoverished HH"].tolist()
nonpov_autism_bar = all_years["Autism Rate in Non-Impoverished HH"].tolist()
siglist = all_years["Autistic Child Difference Significant for Poverty Status"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, pov_autism_bar, color='darkturquoise', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Impoverished Household")
plt.bar(r2, nonpov_autism_bar, color='peru', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Impoverished Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child Autism Rate in Impoverished Vs. Non-Impoverished Households 2006 through 2017")
plt.ylim(0,3.5)

plt.legend()

place = -1

for x,y in zip(x_axis,pov_autism_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,nonpov_autism_bar):

    place = place + 1
    
    if siglist[place]=="Yes":
        label = "{:.1f}*".format(y)
    else:
        label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
plt.text(2005.5,3.1,"* Signifies significant difference between autism rates \n between household types for a given year",
        fontsize=10)
plt.xlabel("Year")
plt.ylabel("Percent of Families with an Autistic Child")

# Save the Figure
plt.savefig(f"../Images/AutismVsPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
# Explore the connection between smoking rates and poverty rates
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.4

# set height of bar
smk_bar = all_years["Percent in Smoking HH"].tolist()
pov_bar = all_years["Percent in Impoverished HH"].tolist()

# set position of the bar on the x-axis
r1 = [x - 0.5*barwidth for x in tick_locations]
r2 = [x + 0.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_bar, color='darksalmon', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Rate")
plt.bar(r2, pov_bar, color='teal', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Poverty Rate")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Is There a Correlation Between Household Poverty and Smoking Status?")
plt.ylim(0,30)

plt.legend()

place = -1

for x,y in zip(x_axis,smk_bar):

    place = place + 1
    
    label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1

for x,y in zip(x_axis,pov_bar):

    place = place + 1
    
    label = "{:.1f}".format(y)

    plt.annotate(label, # this is the text
                 (r2[place]+0.1,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,8), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    

plt.xlabel("Year")
plt.ylabel("Percent of Families")

# Save the Figure
plt.savefig(f"../Images/SmokingVsPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.2

# set height of bar
smk_pov_bar = all_years["Asthma Rate in Smoking Impoverished HH"].tolist()
nonsmk_pov_bar = all_years["Asthma Rate in Non-Smoking Impoverished HH"].tolist()
smk_nonpov_bar = all_years["Asthma Rate in Smoking Non-Impoverished HH"].tolist()
nonsmk_nonpov_bar = all_years["Asthma Rate in Non-Smoking Non-Impoverished HH"].tolist()
siglist = all_years["Asthmatic Child Difference Significant for Smoking Status in Impoverished HH"].tolist()
siglist2 = all_years["Asthmatic Child Difference Significant for Smoking Status in Non-Impoverished HH"].tolist()

# set position of the bar on the x-axis
r1 = [x - 1.5*barwidth for x in tick_locations]
r2 = [x - 0.5*barwidth for x in tick_locations]
r3 = [x + 0.5*barwidth for x in tick_locations]
r4 = [x + 1.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_pov_bar, color='navy', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Impoverished Household")
plt.bar(r2, nonsmk_pov_bar, color='maroon', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Impoverished Household")
plt.bar(r3, smk_nonpov_bar, color='gold', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Non-Impoverished Household")
plt.bar(r4, nonsmk_nonpov_bar, color='forestgreen', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Non-Impoverished Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child Asthma Rate by Poverty and Smoking Status of Households 2006 through 2017")
plt.ylim(0,40)

plt.legend()

place = -1
for x,y in zip(x_axis,smk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1
for x,y in zip(x_axis,nonsmk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r2[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
place = -1
for x,y in zip(x_axis,smk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r3[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
place = -1
for x,y in zip(x_axis,nonsmk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r4[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
plt.text(2005.5,35,"* Signifies significant difference between asthma rates \n     between smoking and non-smoking \n     impoverished household for a given year",
        fontsize=8)
plt.text(2005.5,31,"^ Signifies significant difference between asthma rates \n     between smoking and non-smoking \n     non-impoverished household for a given year",
        fontsize=8)

plt.xlabel("Year")
plt.ylabel("Percent of Families with an Asthmatic Child")

# Save the Figure
plt.savefig(f"../Images/AsthmaVsSmokingPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.2

# set height of bar
smk_pov_bar = all_years["ADHD/ADD Rate in Smoking Impoverished HH"].tolist()
nonsmk_pov_bar = all_years["ADHD/ADD Rate in Non-Smoking Impoverished HH"].tolist()
smk_nonpov_bar = all_years["ADHD/ADD Rate in Smoking Non-Impoverished HH"].tolist()
nonsmk_nonpov_bar = all_years["ADHD/ADD Rate in Non-Smoking Non-Impoverished HH"].tolist()
siglist = all_years["ADHD/ADD Child Difference Significant for Smoking Status in Impoverished HH"].tolist()
siglist2 = all_years["ADHD/ADD Child Difference Significant for Smoking Status in Non-Impoverished HH"].tolist()

# set position of the bar on the x-axis
r1 = [x - 1.5*barwidth for x in tick_locations]
r2 = [x - 0.5*barwidth for x in tick_locations]
r3 = [x + 0.5*barwidth for x in tick_locations]
r4 = [x + 1.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_pov_bar, color='navy', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Impoverished Household")
plt.bar(r2, nonsmk_pov_bar, color='maroon', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Impoverished Household")
plt.bar(r3, smk_nonpov_bar, color='gold', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Non-Impoverished Household")
plt.bar(r4, nonsmk_nonpov_bar, color='forestgreen', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Non-Impoverished Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child ADHD/ADD Rate by Poverty and Smoking Status of Households 2006 through 2017")
plt.ylim(0,25)

plt.legend()

place = -1
for x,y in zip(x_axis,smk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1
for x,y in zip(x_axis,nonsmk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r2[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
place = -1
for x,y in zip(x_axis,smk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    plt.annotate(label, # this is the text
                 (r3[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
place = -1
for x,y in zip(x_axis,nonsmk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r4[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
    
plt.text(2005.5,22,"* Signifies significant difference between ADD/ADHD rates \n     between smoking and non-smoking \n     impoverished household for a given year",
        fontsize=8)
plt.text(2005.5,18,"^ Signifies significant difference between ADD/ADHD rates \n     between smoking and non-smoking \n     non-impoverished household for a given year",
        fontsize=8)

plt.xlabel("Year")
plt.ylabel("Percent of Families with an ADHD/ADD Child")

# Save the Figure
plt.savefig(f"../Images/ADDVsSmokingPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.2

# set height of bar
smk_pov_bar = all_years["Concentration/Emotional/Behavior Rate in Smoking Impoverished HH"].tolist()
nonsmk_pov_bar = all_years["Concentration/Emotional/Behavior Rate in Non-Smoking Impoverished HH"].tolist()
smk_nonpov_bar = all_years["Concentration/Emotional/Behavior Rate in Smoking Non-Impoverished HH"].tolist()
nonsmk_nonpov_bar = all_years["Concentration/Emotional/Behavior Rate in Non-Smoking Non-Impoverished HH"].tolist()
siglist = all_years["Concentration/Emotional/Behavior Difference Significant for Smoking Status in Impoverished HH"].tolist()
siglist2 = all_years["Concentration/Emotional/Behavior Difference Significant for Smoking Status in Non-Impoverished HH"].tolist()

# set position of the bar on the x-axis
r1 = [x - 1.5*barwidth for x in tick_locations]
r2 = [x - 0.5*barwidth for x in tick_locations]
r3 = [x + 0.5*barwidth for x in tick_locations]
r4 = [x + 1.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_pov_bar, color='navy', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Impoverished Household")
plt.bar(r2, nonsmk_pov_bar, color='maroon', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Impoverished Household")
plt.bar(r3, smk_nonpov_bar, color='gold', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Non-Impoverished Household")
plt.bar(r4, nonsmk_nonpov_bar, color='forestgreen', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Non-Impoverished Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Child Behavioral Issues Rate by Poverty and Smoking Status of Households 2006 through 2017")
plt.ylim(0,50)

plt.legend()

place = -1
for x,y in zip(x_axis,smk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1
for x,y in zip(x_axis,nonsmk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r2[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
place = -1
for x,y in zip(x_axis,smk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r3[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
place = -1
for x,y in zip(x_axis,nonsmk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r4[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
    
plt.text(2005.5,45,"* Signifies significant difference between Concentration/ \n     Emotional/Behavior Issues rates between smoking and \n     non-smoking impoverished household for a given year",
        fontsize=8)
plt.text(2005.5,40,"^ Signifies significant difference between Concentration/ \n     Emotional/Behavior Issues rates between smoking and \n     non-smoking non-impoverished household for a given year",
        fontsize=8)

plt.xlabel("Year")
plt.ylabel("Percent of Families with a Child with Behavioral Issues")

# Save the Figure
plt.savefig(f"../Images/BehaviorVsSmokingPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(15,15))

# Set x axis and tick locations()
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

# set bar width
barwidth = 0.2

# set height of bar
smk_pov_bar = all_years["Autism Rate in Smoking Impoverished HH"].tolist()
nonsmk_pov_bar = all_years["Autism Rate in Non-Smoking Impoverished HH"].tolist()
smk_nonpov_bar = all_years["Autism Rate in Smoking Non-Impoverished HH"].tolist()
nonsmk_nonpov_bar = all_years["Autism Rate in Non-Smoking Non-Impoverished HH"].tolist()
siglist = all_years["Autistic Child Difference Significant for Smoking Status in Impoverished HH"].tolist()
siglist2 = all_years["Autistic Child Difference Significant for Smoking Status in Non-Impoverished HH"].tolist()

# set position of the bar on the x-axis
r1 = [x - 1.5*barwidth for x in tick_locations]
r2 = [x - 0.5*barwidth for x in tick_locations]
r3 = [x + 0.5*barwidth for x in tick_locations]
r4 = [x + 1.5*barwidth for x in tick_locations]

plt.figure(figsize=(10,5))
plt.bar(r1, smk_pov_bar, color='navy', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Impoverished Household")
plt.bar(r2, nonsmk_pov_bar, color='maroon', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Impoverished Household")
plt.bar(r3, smk_nonpov_bar, color='gold', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Smoking Non-Impoverished Household")
plt.bar(r4, nonsmk_nonpov_bar, color='forestgreen', alpha = 0.9, align="center", width=barwidth, edgecolor = 'white', label="Non-Smoking Non-Impoverished Household")
plt.xticks(tick_locations,all_years['Year'].tolist())
plt.title("Autism Rate by Poverty and Smoking Status of Households 2006 through 2017")
plt.ylim(0,6)

plt.legend()

place = -1
for x,y in zip(x_axis,smk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r1[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center

place = -1
for x,y in zip(x_axis,nonsmk_pov_bar):
    place = place + 1
    if siglist[place]=="Yes":
        label = "*"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r2[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
place = -1
for x,y in zip(x_axis,smk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    else: 
        label = ''
        
    plt.annotate(label, # this is the text
                 (r3[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
place = -1
for x,y in zip(x_axis,nonsmk_nonpov_bar):
    place = place + 1
    if siglist2[place]=="Yes":
        label = "^"
    else: 
        label = ''
    plt.annotate(label, # this is the text
                 (r4[place],y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,4), # distance from text to points (x,y)
                 ha='center',
                 fontsize=8) # horizontal alignment can be left, right or center
    
    
plt.text(2005.5,5,"* Signifies significant difference between Autism/ \n     rates between smoking and \n     non-smoking impoverished household for a given year",
        fontsize=8)
plt.text(2005.5,4,"^ Signifies significant difference between Autism/ \n     rates between smoking and \n     non-smoking non-impoverished household for a given year",
        fontsize=8)

plt.xlabel("Year")
plt.ylabel("Percent of Families with an Autistic Child")

# Save the Figure
plt.savefig(f"../Images/AutismVsSmokingPoverty.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="1000">
