# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from scipy import stats
import os
import matplotlib.pyplot as plt

# %%
# Output the allyears dataframe for further analysis
outdatapath = os.path.join('..','output_data',f"AllMeansAndTests.csv")
all_years=pd.read_csv(outdatapath)
all_years.head()
# Out:
#    Year  Count in Smoking HH  Asthma Rate in Smoking HH  \
# 0  2006                 1727                  17.081644
# 1  2007                 1415                  17.667845
# 2  2008                 1450                  17.517241
# 3  2009                 1846                  18.093174
# 4  2010                 1700                  15.882353
#
#    Count Asthma in Smoking HH  \
# 0                         295
# 1                         250
# 2                         254
# 3                         334
# 4                         270
#
#    Asthmatic Child Difference P-Value for Smoking Status  \
# 0                                           0.000009
# 1                                           0.000004
# 2                                           0.000163
# 3                                           0.000002
# 4                                           0.011216
#
#   Asthmatic Child Difference Significant for Smoking Status  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    Autism Rate in Smoking HH  Count Autism in Smoking HH  \
# 0                   0.405327                           7
# 1                   0.636042                           9
# 2                   0.896552                          13
# 3                   1.462622                          27
# 4                   1.235294                          21
#
#    Autistic Child Difference P-Value for Smoking Status  \
# 0                                           0.115221
# 1                                           0.937558
# 2                                           0.583443
# 3                                           0.057217
# 4                                           0.166156
#
#   Autistic Child Difference Significant for Smoking Status  ...  \
# 0                                                 No        ...
# 1                                                 No        ...
# 2                                                 No        ...
# 3                                                 No        ...
# 4                                                 No        ...
#
#    Asthma Rate in Non-Smoking Non-Impoverished HH  \
# 0                                       12.245253
# 1                                       12.058879
# 2                                       12.853799
# 3                                       12.796525
# 4                                       13.142563
#
#    Count Asthma in Non-Smoking Non-Impoverished HH  \
# 0                                              703
# 1                                              639
# 2                                              604
# 3                                              766
# 4                                              767
#
#    Autism Rate in Non-Smoking Non-Impoverished HH  \
# 0                                        0.731580
# 1                                        0.717116
# 2                                        0.808683
# 3                                        0.935516
# 4                                        0.873886
#
#   Count Autism in Non-Smoking Non-Impoverished HH  \
# 0                                              42
# 1                                              38
# 2                                              38
# 3                                              56
# 4                                              51
#
#    ADHD/ADD Rate in Non-Smoking Non-Impoverished HH  \
# 0                                          5.277826
# 1                                          4.868843
# 2                                          6.107682
# 3                                          5.529569
# 4                                          5.894448
#
#    Count ADHD/ADD in Non-Smoking Non-Impoverished HH  \
# 0                                                303
# 1                                                258
# 2                                                287
# 3                                                331
# 4                                                344
#
#    Count Concentration/Emotional/Behavior in Non-Smoking Non-Impoverished HH  \
# 0                                                767
# 1                                                657
# 2                                                595
# 3                                                703
# 4                                                854
#
#   Concentration/Emotional/Behavior Rate in Non-Smoking Non-Impoverished HH  \
# 0                                          13.360042
# 1                                          12.398566
# 2                                          12.662269
# 3                                          11.744069
# 4                                          14.633310
#
#    Percent in Smoking Non-Impoverished HH  \
# 0                               19.231851
# 1                               16.773991
# 2                               18.660204
# 3                               17.763429
# 4                               17.031561
#
#    Percent in Non-Smoking Non-Impoverished HH
# 0                                   80.768149
# 1                                   83.226009
# 2                                   81.339796
# 3                                   82.236571
# 4                                   82.968439
#
# [5 rows x 113 columns]

# %%
# Set x axis and tick locations
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

plt.figure(figsize=(10,5))
plt.bar(x_axis, all_years["Asthma Rate in Smoking HH"], color='b', alpha=0.7, align="center")
plt.bar(x_axis, all_years["Asthma Rate in Non-Smoking HH"], color='y', alpha=0.7, align="center")
plt.xticks(tick_locations,all_years['Year'], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x236975080b8>,
#   <matplotlib.axis.XTick at 0x236968376d8>,
#   <matplotlib.axis.XTick at 0x236960f4550>,
#   <matplotlib.axis.XTick at 0x2369755f358>,
#   <matplotlib.axis.XTick at 0x2369755f7b8>,
#   <matplotlib.axis.XTick at 0x2369755fc88>,
#   <matplotlib.axis.XTick at 0x23697568198>,
#   <matplotlib.axis.XTick at 0x23697568668>,
#   <matplotlib.axis.XTick at 0x23697568b38>,
#   <matplotlib.axis.XTick at 0x2369756e0b8>,
#   <matplotlib.axis.XTick at 0x2369756e518>,
#   <matplotlib.axis.XTick at 0x23697568748>],
#  <a list of 12 Text xticklabel objects>)

# %%
plt.figure(figsize=(10,5))
plt.bar(x_axis, all_years["Percent in Impoverished HH"], color='b', alpha=0.7, align="center")
plt.xticks(tick_locations,all_years['Year'], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x23696e683c8>,
#   <matplotlib.axis.XTick at 0x2369684f940>,
#   <matplotlib.axis.XTick at 0x2369684f668>,
#   <matplotlib.axis.XTick at 0x23696eb82b0>,
#   <matplotlib.axis.XTick at 0x23696eb8710>,
#   <matplotlib.axis.XTick at 0x23696eb8a90>,
#   <matplotlib.axis.XTick at 0x23696eb8f60>,
#   <matplotlib.axis.XTick at 0x23696ebf470>,
#   <matplotlib.axis.XTick at 0x23696ebf940>,
#   <matplotlib.axis.XTick at 0x23696ebfe10>,
#   <matplotlib.axis.XTick at 0x23696ec5320>,
#   <matplotlib.axis.XTick at 0x23696ec57f0>],
#  <a list of 12 Text xticklabel objects>)

# %%
plt.figure(figsize=(10,5))
plt.bar(x_axis, all_years["Percent in Smoking HH"], color='b', alpha=0.7, align="center")
plt.xticks(tick_locations,all_years['Year'], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x2369618d588>,
#   <matplotlib.axis.XTick at 0x23696183518>,
#   <matplotlib.axis.XTick at 0x23696183b38>,
#   <matplotlib.axis.XTick at 0x23696811b70>,
#   <matplotlib.axis.XTick at 0x23696811940>,
#   <matplotlib.axis.XTick at 0x2369681b3c8>,
#   <matplotlib.axis.XTick at 0x2369681b898>,
#   <matplotlib.axis.XTick at 0x2369681bd68>,
#   <matplotlib.axis.XTick at 0x23696822278>,
#   <matplotlib.axis.XTick at 0x23696822748>,
#   <matplotlib.axis.XTick at 0x23696822c18>,
#   <matplotlib.axis.XTick at 0x2369682a160>],
#  <a list of 12 Text xticklabel objects>)

# %%
# Set x axis and tick locations
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

plt.figure(figsize=(10,5))
plt.bar(x_axis, all_years["Autism Rate in Smoking HH"], color='b', alpha=0.7, align="center")
plt.bar(x_axis, all_years["Autism Rate in Non-Smoking HH"], color='y', alpha=0.7, align="center")
plt.xticks(tick_locations,all_years['Year'], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x23692944630>,
#   <matplotlib.axis.XTick at 0x236928da080>,
#   <matplotlib.axis.XTick at 0x236960f4630>,
#   <matplotlib.axis.XTick at 0x23696157400>,
#   <matplotlib.axis.XTick at 0x23696157860>,
#   <matplotlib.axis.XTick at 0x23696157d30>,
#   <matplotlib.axis.XTick at 0x2369615e240>,
#   <matplotlib.axis.XTick at 0x2369615e710>,
#   <matplotlib.axis.XTick at 0x2369615ebe0>,
#   <matplotlib.axis.XTick at 0x2369615e7f0>,
#   <matplotlib.axis.XTick at 0x236961579b0>,
#   <matplotlib.axis.XTick at 0x236961672e8>],
#  <a list of 12 Text xticklabel objects>)

# %%
# Set x axis and tick locations
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

plt.figure(figsize=(10,10))
plt.bar(x_axis, all_years["ADHD/ADD Rate in Smoking HH"], color='b', alpha=0.7, align="center")
plt.bar(x_axis, all_years["ADHD/ADD Rate in Non-Smoking HH"], color='y', alpha=0.7, align="center")
plt.xticks(tick_locations,all_years['Year'], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x2369238d0b8>,
#   <matplotlib.axis.XTick at 0x2369237da58>,
#   <matplotlib.axis.XTick at 0x2369237dac8>,
#   <matplotlib.axis.XTick at 0x2369240f0f0>,
#   <matplotlib.axis.XTick at 0x2369240f518>,
#   <matplotlib.axis.XTick at 0x2369240f9e8>,
#   <matplotlib.axis.XTick at 0x2369240feb8>,
#   <matplotlib.axis.XTick at 0x236924143c8>,
#   <matplotlib.axis.XTick at 0x23692414898>,
#   <matplotlib.axis.XTick at 0x23692414d68>,
#   <matplotlib.axis.XTick at 0x2369241c278>,
#   <matplotlib.axis.XTick at 0x23692414860>],
#  <a list of 12 Text xticklabel objects>)

# %%
# Set x axis and tick locations
x_axis = np.arange(2006,2018)
tick_locations = [value for value in x_axis]

plt.figure(figsize=(10,10))
plt.bar(x_axis, all_years["ADHD/ADD Rate in Smoking HH"], color='b', alpha=0.7, align="center")
plt.bar(x_axis, all_years["ADHD/ADD Rate in Non-Smoking HH"], color='y', alpha=0.7, align="center")
plt.xticks(tick_locations,all_years['Year'], rotation="vertical")
