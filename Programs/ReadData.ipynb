# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from scipy import stats
import os

# %%
datapath = os.path.join('..','data','2014')
sasfile2read=os.path.join(datapath,'samchild.sas')
datfile2read=os.path.join(datapath,'samchild.dat')

# %%
f = open(sasfile2read, "r") 

line_starting_input = 0
line_ending_input = 0
line_number = -1

input_lines = []

for x in f:

    line_number = line_number + 1
    
    # remove carriage returns
    x = x.replace("\n","")
        
    # The input lines start at the input statement that is not part of a comment and does not contain a semi-colon
    if x.upper().find('INPUT') > -1 and x.upper().find(';') == -1 and x.upper().find('*') == -1:
        line_starting_input = line_number

    # The input statement ends with the first semi-colon after it starts
    if line_starting_input > 0 and line_ending_input == 0 and x.find(';') > -1:
        line_ending_input = line_number
        
    # If this current line of code is...
    # 1. between the start and stop of the input 
    # 2. Not a comment line  (Note that the programs we are looking at have only full-line comments with no code)
    # 3. Not a blank line
    # Then we save it as one of the code lines
    if line_starting_input > 0 and line_number >= line_starting_input and \
        (line_ending_input == 0 or line_number <= line_ending_input) and \
        x.upper().find('*') == -1 and x.replace(" ","") != '':
        input_lines.append(x)
    

print(f"Input Statement starts at line {line_starting_input}")
print(f"Input Statement ends at line {line_ending_input}")
print(f"Total Lines: {line_number}")
f.close

#print(input_lines)

for line in input_lines:
    print(f"Code Line:  {line}")
# Out:
# Input Statement starts at line 646
# Input Statement ends at line 803
# Total Lines: 1244
# Code Line:     INPUT
# Code Line:        RECTYPE       1 -   2    SRVY_YR       3 -   6
# Code Line:        HHX      $    7 -  12    INTV_QRT     13 -  13
# Code Line:        INTV_MON     14 -  15    FMX      $   16 -  17
# Code Line:        FPX      $   18 -  19    WTIA_SC      20 -  26 .1
# Code Line:        WTFA_SC      27 -  32
# Code Line:        REGION       33 -  33    STRAT_P      34 -  36
# Code Line:        PSU_P        37 -  38
# Code Line:        SEX          39 -  39    HISPAN_I     40 -  41
# Code Line:        RACERPI2     42 -  43    MRACRPI2     44 -  45
# Code Line:        MRACBPI2     46 -  47    AGE_P        48 -  49
# Code Line:        CSRESPNO $   50 -  51    CSRELTVP     52 -  52
# Code Line:        LATEINTC     53 -  53
# Code Line:        FDRN_FLG     54 -  54
# Code Line:        TOTOZ_P      55 -  57    BWTGRM_P     58 -  61
# Code Line:        CHGHT_TC     62 -  63    CWGHT_TC     64 -  66
# Code Line:        BMI_SC       67 -  70    AMR1R        71 -  71
# Code Line:        AODD1        72 -  72    ADD2         73 -  73
# Code Line:        AMR2R        74 -  74    AUTISM       75 -  75
# Code Line:        AODD2        76 -  76    CCONDRR1     77 -  77
# Code Line:        CCONDRR2     78 -  78    CCONDRR3     79 -  79
# Code Line:        CCONDRR4     80 -  80    CCONDRR5     81 -  81
# Code Line:        CCONDRR6     82 -  82    CCONDRR7     83 -  83
# Code Line:        CCONDRR8     84 -  84    CCONDRR9     85 -  85
# Code Line:        CPOX         86 -  86    CPOX12MO     87 -  87
# Code Line:        CASHMEV      88 -  88    CASSTILL     89 -  89
# Code Line:        CASHYR       90 -  90    CASERYR1     91 -  91
# Code Line:        HAYF1        92 -  92    RALLG1       93 -  93
# Code Line:        DALLG1       94 -  94    SALLG1       95 -  95
# Code Line:        DIARH1       96 -  96    ANEMIA1      97 -  97
# Code Line:        EARINF1      98 -  98    SEIZE1       99 -  99
# Code Line:        HAYF2       100 - 100    RALLG2      101 - 101
# Code Line:        DALLG2      102 - 102    SALLG2      103 - 103
# Code Line:        DIARH2      104 - 104    ANEMIA2     105 - 105
# Code Line:        FHEAD       106 - 106    EARINF2     107 - 107
# Code Line:        SEIZE2      108 - 108    STUTTER     109 - 109
# Code Line:        CHSTATYR    110 - 110    SCHDAYR1    111 - 113
# Code Line:        CCOLD2W     114 - 114    CINTIL2W    115 - 115
# Code Line:        CHEARST2    116 - 116    CHRWORS     117 - 117
# Code Line:        CHRWORSE    118 - 118    CHRWHIS1    119 - 119
# Code Line:        CHRTALK1    120 - 120    CHRSHOU1    121 - 121
# Code Line:        CHRSPEA1    122 - 122    CHRCOCR1    123 - 123
# Code Line:        CHRCOCI1    124 - 124    CHRFAM      125 - 125
# Code Line:        CHRMIS      126 - 126    CHRUNDST    127 - 127
# Code Line:        CHRUNDNS    128 - 128    CHEARAG1    129 - 130
# Code Line:        CHRCAUS1    131 - 132    CHRPRBHP    133 - 133
# Code Line:        CHRENT      134 - 134    CHREHDI     135 - 135
# Code Line:        CHREIAGE    136 - 137    CHRTUBE     138 - 138
# Code Line:        CHRTBAGE    139 - 140    CHRTSCH     141 - 141
# Code Line:        CHRTSCHM    142 - 142    CHRTSCHR    143 - 143
# Code Line:        CHRTEST     144 - 144    CHRAIDNW    145 - 145
# Code Line:        CHRAIDLG    146 - 147    CHRAIDYR    148 - 148
# Code Line:        CHRAIDEV    149 - 149    CHRAIDRC    150 - 150
# Code Line:        CHRAIDLP    151 - 152    CHRAIDOF    153 - 153
# Code Line:        CHRAID01    154 - 154    CHRAID02    155 - 155
# Code Line:        CHRAID03    156 - 156    CHRAID04    157 - 157
# Code Line:        CHRAID05    158 - 158    CHRAID06    159 - 159
# Code Line:        CHRAID07    160 - 160    CHRAID08    161 - 161
# Code Line:        CHRAID09    162 - 162    CHRAID10    163 - 163
# Code Line:        CHRAID11    164 - 164    CHRAUD      165 - 165
# Code Line:        CHRALDS     166 - 166    CHRALD01    167 - 167
# Code Line:        CHRALD02    168 - 168    CHRALD03    169 - 169
# Code Line:        CHRALD04    170 - 170    CHRALD05    171 - 171
# Code Line:        CHRALD06    172 - 172    CHRALD07    173 - 173
# Code Line:        CHRALD08    174 - 174    CHRALD09    175 - 175
# Code Line:        CHRALD10    176 - 176    CHRALD11    177 - 177
# Code Line:        CHRALD12    178 - 178    CHRFIRE     179 - 179
# Code Line:        CHRFRCRK    180 - 180    CHRTOTR     181 - 181
# Code Line:        CHRFRPRT    182 - 182    CHRWKVLN    183 - 183
# Code Line:        CHRWKVLT    184 - 185    CHRWKPRT    186 - 186
# Code Line:        CHRLESNS    187 - 187    CHRLST01    188 - 188
# Code Line:        CHRLST02    189 - 189    CHRLST03    190 - 190
# Code Line:        CHRLST04    191 - 191    CHRLST05    192 - 192
# Code Line:        CHRLST06    193 - 193    CHRLST07    194 - 194
# Code Line:        CHRLST08    195 - 195    CHRLST09    196 - 196
# Code Line:        CHRLST10    197 - 197    CHRLST11    198 - 198
# Code Line:        CHRLST12    199 - 199    CHRLSPRT    200 - 200
# Code Line:        CHRINT      201 - 201    CHRINTHL    202 - 202
# Code Line:        CHRINTHA    203 - 203    CHRINTHP    204 - 204
# Code Line:        CHRINHPR    205 - 205    CVISION     206 - 206
# Code Line:        CBLIND      207 - 207    IHSPEQ      208 - 208
# Code Line:        IHMOB       209 - 209    IHMOBYR     210 - 210
# Code Line:        PROBRX      211 - 211    LEARND      212 - 212
# Code Line:        MHIBOY2     213 - 214    CMHAGM15    215 - 215
# Code Line:        MHIGRL2     216 - 217    CMHAGF15    218 - 218
# Code Line:        CUSUALPL    219 - 219    CPLKIND     220 - 220
# Code Line:        CHCPLROU    221 - 221    CHCPLKND    222 - 222
# Code Line:        CHCCHGYR    223 - 223    CHCCHGHI    224 - 224
# Code Line:        CNOUSPL1    225 - 225    CNOUSPL2    226 - 226
# Code Line:        CNOUSPL3    227 - 227    CNOUSPL4    228 - 228
# Code Line:        CNOUSPL5    229 - 229    CNOUSPL6    230 - 230
# Code Line:        CNOUSPL7    231 - 231    CNOUSPL8    232 - 232
# Code Line:        CNOUSPL9    233 - 233    CPRVTRYR    234 - 234
# Code Line:        CPRVTRFD    235 - 235    CDRNANP     236 - 236
# Code Line:        CDRNAI      237 - 237    CHCDLYR1    238 - 238
# Code Line:        CHCDLYR2    239 - 239    CHCDLYR3    240 - 240
# Code Line:        CHCDLYR4    241 - 241    CHCDLYR5    242 - 242
# Code Line:        CHCAFYR     243 - 243    CHCAFYRN    244 - 244
# Code Line:        CHCAFYRF    245 - 245    CHCAFYR1    246 - 246
# Code Line:        CHCAFYR2    247 - 247    CHCAFYR3    248 - 248
# Code Line:        CHCAFYR4    249 - 249    CHCAFYR5    250 - 250
# Code Line:        CHCAFYR6    251 - 251    CDNLONGR    252 - 252
# Code Line:        CHCSYR11    253 - 253    CHCSYR12    254 - 254
# Code Line:        CHCSYR13    255 - 255    CHCSYR14    256 - 256
# Code Line:        CHCSYR1     257 - 257    CHCSYR2     258 - 258
# Code Line:        CHCSYR3     259 - 259    CHCSYR4     260 - 260
# Code Line:        CHCSYR5     261 - 261    CHCSYR6     262 - 262
# Code Line:        CHCSYR7     263 - 263    CHCSYR81    264 - 264
# Code Line:        CHCSYR82    265 - 265    CHCSYR10    266 - 266
# Code Line:        CHCSYREM    267 - 267    CHPXYR_C    268 - 268
# Code Line:        CHERNOY2    269 - 270    CERVISND    271 - 271
# Code Line:        CERHOS      272 - 272    CERREA1R    273 - 273
# Code Line:        CERREA2R    274 - 274    CERREA3R    275 - 275
# Code Line:        CERREA4R    276 - 276    CERREA5R    277 - 277
# Code Line:        CERREA6R    278 - 278    CERREA7R    279 - 279
# Code Line:        CERREA8R    280 - 280    CHCHYR      281 - 281
# Code Line:        CHCHMOYR    282 - 283    CHCHNOY2    284 - 285
# Code Line:        CHCNOYR2    286 - 287    CSRGYR      288 - 288
# Code Line:        RSRGNOYR    289 - 290    CMDLONGR    291 - 291
# Code Line:        RSCL2_C2    292 - 292    RSCL2_E2    293 - 293
# Code Line:        RSCL3_E3    294 - 294    RSCL5_P5    295 - 295
# Code Line:        RSCL5_H5    296 - 296    RSCL6       297 - 297
# Code Line:        CSHFLU12    298 - 298    CSHFLUNM    299 - 299
# Code Line:        CSHFLUM1    300 - 301    CSHFLUY1    302 - 305
# Code Line:        CSHSPFL1    306 - 306    CSHFLUM2    307 - 308
# Code Line:        CSHFLUY2    309 - 312    CSHSPFL2    313 - 313
# Code Line:  ;

# %%
# create lists for variable names, starting position, ending position, and character flag
varnames=[]
starts=[]
ends=[]
charflags=[]
widths=[]
varcount = -1

# loop through the input lines and pull the variable information into the lists
for line in input_lines:

    # take off leading and trailing spaces
    line = line.strip()

    # The dash tells us how many variables are specified in the line of code
    # This particular codes has either 0 (count=0), 1 (count = 1), or 2 (count = 2)
    if line.count('-') > 0:
        
        templist = line.split()
       
        for word in templist:
            
            # remove any spaces or semi-colons in the word
            word = word.replace(' ','')
            word = word.replace(';','')
                        
            # Test to see if the word starts with a letter or underscore. If so, this is a variable name.
            if word[0].isalpha()==True or word[0]== "_":
                                
                # Increment the number of variables
                varcount = varcount + 1
                
                # Store the variable name with no spaces
                varnames.append(word)
                
                # Set the type as numeric. We will reset this if we see a $ before the start/end
                charflags.append(False)
                
                # Set indicator to say if we have determined the start
                found_start = False
                
            # Test to see if the word is $.  If so, change the character flag for this variable
            elif word == '$':
                charflags[varcount] = True
           
            # If this is numeric, then it is either the start or stop place.
            elif word.isnumeric()==True:
                                
                # If we have not yet found a start then this must be the start
                # Otherwise it must be the end. Set the end and caluclate the width
                if found_start == False:
                    
                    starts.append(word)
                    found_start = True                    
                    
                else:
                    ends.append(word)
                    widths.append(int(ends[varcount]) - int(starts[varcount]) + 1)

# %%
vlen = len(varnames)
clen = len(charflags)
slen = len(starts)
elen = len(ends)
wlen = len(widths)

print(f"Varcount should be one less than the length of the lists (accounting for 0 index) = {varcount}")
print(f"First 5 of {vlen} varnames = {varnames[0]},{varnames[1]},{varnames[2]},{varnames[3]},{varnames[4]}")
print(f"First 5 of {clen} charflags = {charflags[0]}, {charflags[1]}, {charflags[2]}, {charflags[3]}, {charflags[4]}")
print(f"First 5 of {slen} starts = {starts[0]}, {starts[1]}, {starts[2]}, {starts[3]}, {starts[4]},")
print(f"First 5 of {elen} ends = {ends[0]}, {ends[1]}, {ends[2]}, {ends[3]}, {ends[4]}")
print(f"First 5 of {wlen} widths = {widths[0]}, {widths[1]}, {widths[2]}, {widths[3]}, {widths[4]}")
# Out:
# Varcount should be one less than the length of the lists (accounting for 0 index) = 245
# First 5 of 246 varnames = RECTYPE,SRVY_YR,HHX,INTV_QRT,INTV_MON
# First 5 of 246 charflags = False, False, True, False, False
# First 5 of 246 starts = 1, 3, 7, 13, 14,
# First 5 of 246 ends = 2, 6, 12, 13, 15
# First 5 of 246 widths = 2, 4, 6, 1, 2

# %%
# Use the lists we created to read the data from the flat file (fwf=fixed width file)
df_sc_2014 = pd.read_fwf(datfile2read, widths=widths, names=varnames,parse_dates=True)
df_sc_2014.head()
# Out:
#    RECTYPE  SRVY_YR  HHX  INTV_QRT  INTV_MON  FMX  FPX  WTIA_SC  WTFA_SC  \
# 0       40     2014   13         1         1    1    3    49029     6039
# 1       40     2014   20         1         2    1    4    21905     3145
# 2       40     2014   25         1         1    1    4    38460     5497
# 3       40     2014   29         1         1    1    5     3742      592
# 4       40     2014   34         1         2    1    2    49141     6553
#
#    REGION  ...  RSCL5_H5  RSCL6  CSHFLU12  CSHFLUNM  CSHFLUM1  CSHFLUY1  \
# 0       4  ...       NaN    NaN         2       NaN       NaN       NaN
# 1       4  ...       NaN    NaN         1       1.0       9.0    2013.0
# 2       2  ...       2.0    0.0         2       NaN       NaN       NaN
# 3       2  ...       0.0    0.0         1       1.0      10.0    2013.0
# 4       1  ...       2.0    0.0         2       NaN       NaN       NaN
#
#    CSHSPFL1  CSHFLUM2  CSHFLUY2  CSHSPFL2
# 0       NaN       NaN       NaN       NaN
# 1       2.0       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN
# 3       1.0       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN
#
# [5 rows x 246 columns]

# %%
# convert columns to string if they were specified that way in the sas code
for i in range(len(charflags)):
    if charflags[i]==True:
        df_sc_2014[varnames[i]]=df_sc_2014[varnames[i]].astype(str)
df_sc_2014.dtypes
# Out:
# RECTYPE       int64
# SRVY_YR       int64
# HHX          object
# INTV_QRT      int64
# INTV_MON      int64
# FMX          object
# FPX          object
# WTIA_SC       int64
# WTFA_SC       int64
# REGION        int64
# STRAT_P       int64
# PSU_P         int64
# SEX           int64
# HISPAN_I      int64
# RACERPI2      int64
# MRACRPI2      int64
# MRACBPI2      int64
# AGE_P         int64
# CSRESPNO     object
# CSRELTVP      int64
# LATEINTC      int64
# FDRN_FLG      int64
# TOTOZ_P       int64
# BWTGRM_P      int64
# CHGHT_TC    float64
# CWGHT_TC    float64
# BMI_SC      float64
# AMR1R       float64
# AODD1       float64
# ADD2        float64
#              ...
# CERHOS      float64
# CERREA1R    float64
# CERREA2R    float64
# CERREA3R    float64
# CERREA4R    float64
# CERREA5R    float64
# CERREA6R    float64
# CERREA7R    float64
# CERREA8R    float64
# CHCHYR        int64
# CHCHMOYR    float64
# CHCHNOY2    float64
# CHCNOYR2      int64
# CSRGYR        int64
# RSRGNOYR    float64
# CMDLONGR      int64
# RSCL2_C2    float64
# RSCL2_E2    float64
# RSCL3_E3    float64
# RSCL5_P5    float64
# RSCL5_H5    float64
# RSCL6       float64
# CSHFLU12      int64
# CSHFLUNM    float64
# CSHFLUM1    float64
# CSHFLUY1    float64
# CSHSPFL1    float64
# CSHFLUM2    float64
# CSHFLUY2    float64
# CSHSPFL2    float64
# Length: 246, dtype: object
