# %%
# %matplotlib notebook
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np

# %%
data = 'AllMeansAndTests.csv'

# %%
df = pd.read_csv(data)
df
# Out:
#     Year  Count in Smoking HH  Asthma Rate in Smoking HH  \
# 0   2006                 1727                  17.081644
# 1   2007                 1415                  17.667845
# 2   2008                 1450                  17.517241
# 3   2009                 1846                  18.093174
# 4   2010                 1700                  15.882353
# 5   2011                 2023                  17.498764
# 6   2012                 2048                  16.943359
# 7   2013                 1922                  17.013528
# 8   2014                 1929                  17.055469
# 9   2015                 1650                  16.848485
# 10  2016                 1510                  16.556291
# 11  2017                 1106                  16.003617
#
#     Count Asthma in Smoking HH  \
# 0                          295
# 1                          250
# 2                          254
# 3                          334
# 4                          270
# ...
